# %% [markdown]
# # UMA BREVE INTRODUÇÃO À MODELAGEM MOLECULAR UTILIZANDO RECURSOS DO SOFTWARE M3L

# %% [markdown]
# # Motivação
# * O trabalho pode ser realizado de maneira não-presencial;
# * O custo financeiro devido a infraestrutura pode ser amenizado com o desenvolvimento de novas metodologias, softwares melhores e processadores cada vez mais rápidos;
# * A quantidade de publicações envolvendo dinâmica molecular ou monte carlo vem crescendo a cada ano desde 2014 [^1].
#
# [^1]: https://doi.org/10.1038/s41598-020-71936-5

# %% [markdown]
# # Modelagem molecular
#
# * O custo computacional aumenta com a quantidade de átomos e interações;
# * A precisão diminui com a quantidade de átomos;
# * Para reduzir o custo computacional, a estratégia seria diminuir o nível de detalhamento.
#
# <p style="text-align: center"><img src="metodos-comparacao.png" width="500"></p>

# %% [markdown]
# # Dinâmica molecular

# %% [markdown]
# # Campo de força
# O campo de força define o conjunto de interações intramoleculares e intermoleculares. As interações intramoleculares são definidas predominantemente por funções harmônicas e anarmônicas (Morse [^1] [1])
# ![campo_forca](montagem-moleculas.jpg)
# [^1]: https://flavianowilliams.github.io/education/courses/quantum_chemistry/harmonic_oscilator/index.html#1

# %% [markdown]
# # Campo de força
# As interações intra/intermoleculares ocorrem em nível subatômico, onde devemos tratar o sistema a partir da equação de Schroedinger,
# $$H\Psi = E\Psi$$
# A hamiltoniana deve incluir todas as interações possíveis, ou seja, interações do tipo *elétron-elétron*, *próton-próton* e *elétron-próton*, envolvendo o núcleo atômico e os elétrons na eletrosfera,
# \begin{eqnarray*}
#   H = & - & \overbrace{\sum_{A=1}^{M}\frac{1}{2}\nabla^2_A+\sum_{A=1}^{M}\sum_{B>A}^{M}\frac{Z_AZ_B}{R_{AB}}}^{\text{parte nuclear}}-\\
#   & - & \overbrace{\sum_{i=1}^{N}\frac{1}{2}\nabla^2_i-\sum_{i=1}^{N}\sum_{A=1}^{M}\frac{Z_A}{r_{iA}}+\sum_{i=1}^{N}\sum_{j>1}^{N}\frac{1}{i_{ij}}.}^{\text{parte eletrônica}}
# \end{eqnarray*}

# %% [markdown]
# # Sistema
# O sistema é formado pelas coordenadas atômicas (posição, velocidade e força), temperatura, pressão, volume e energia potencial e cinética total (a energia total é a soma das energias cinéticas e potencial)
# ![campo_forca](H2O-298K.gif)

# %% [markdown]
# # Ensemble estatístico
#
# * Modelo teórico utilizando métodos estatísticos para reproduzir a evolução temporal de sistemas termodinâmicos
# * Os ensembles mais utilizados em dinâmica molecular são o microcanônico (NVE), canônico (NVT) e ensemble NPT.

# %% [markdown]
# # O pacote M3L
# * M3L é um pacote computacional open source disponível no repositório [TestPyPi](https://test.pypi.org/project/m3l/);
# * O pacote utiliza como principal dependência o pacote numpy para o desenvolvimento do cálculo numérico;
# * Inicialmente deve-se criar um ambiente virtual python e em seguida instalar o pacote M3L;
# * Em seguida três objetos devem definidos:
#   * objeto que representa o sistema físico a nível molecular;
#   * objeto que representa o campo de força que descreve detalhadamente as interações interatômicas;
#   * objeto que representa o ensemble termodinâmico definindo a transformação termodinâmica.

# %% [markdown]
# # O pacote M3L
# M3L pode ser instalado no ambiente virtual utilizando o comando pip install

# %%
pip install -i https://test.pypi.org/simple/ m3l --extra-index-url https://pypi.org/simple/
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple/
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Sistema

# %%
# carregando sistema físico
url = 'https://raw.githubusercontent.com/flavianowilliams/Notebooks/master/M3L/argon/Ar_94K_1atm.json'
from urllib.request import urlopen
file = urlopen(url)
with open('sistema.json','wb') as output:
  output.write(file.read())
#
# carregando sistema físico
from m3l.structure import System as sys
import json
#
system = sys()
system.loadSystem('sistema.json')
#
# convertendo as unidades de medida
system.convertUnits()

# %% [markdown]
# # Campo de força

# %%
# definindo o modelo de interação entre os átomos (campo de força)      
import m3l.force_field as ff
from m3l.force_field import Intermolecular as interff
from m3l.force_field import Molecules as mo
class Forces(ff.ForceField2):
    def __init__(self):
        super().__init__()
        self.van_der_waals = self.sites(
            interff.site(1, 1, 0.2385, 3.4), #site ID, atomic charge, Lennard-Jones parameters
        )
        self.electrostatic = 'coulomb'
        self.convertUnits()
#        self.molecules = mo.molecule(1),
#        )
#    def intermolecular(self.van_der_waals, rvdw = 11.0, rcoul = 11.0)
#        return self.van_der_waals
#        
model = Forces()

# %% [markdown]
# # Ensemble termodinâmico

# %%
# definindo o modelo estatístico (ensemble)
from m3l.molecular_dynamics import Ensemble as en
#
ensemble = en(temp_bath = 94.0, timestep = 1.0e-3, force_field = model())
#ensemble = en(temp_bath = 94, press_bath = 1.0, timestep = 1.0e-3, force_field = model())

# %% [markdown]
# # Ciclo MD

# %%
# O ciclo MD pode ser reproduzido utilizando o bloco de repetição do python
nsteps = 100
for i in range(nsteps):
    system = ensemble(system)

# %% [markdown]
# # Ciclo MD
# ## Gravando dados em arquivo csv

# %%
# O ciclo MD pode ser reproduzido utilizando o bloco de repetição do python
import csv
#
nsteps = 100
with open('arquivo.csv', 'w') as arquivo:
    file = csv.DictWriter(arquivo, fieldnames = ['tempo', 'temperatura'])
    file.writeheader()
    for i in range(nsteps):
        system = ensemble(system)
        tempo = (i+1)*ensemble.timestep/system.TIMECONV
        temperatura = system.temperature/system.TEMPCONV
        file.writerow({
            'tempo': tempo,
            'temperatura': temperatura
        })

# %%
# !ls -lh *.csv
# Out:
# -rw-r--r-- 1 flaviano flaviano 35K set 11 10:19 arquivo.csv

# %% [markdown]
# # Ciclo MD
# ## Carregando dados gravado no arquivo csv

# %%
with open('arquivo.csv', 'r') as arquivo:
    file = csv.DictReader(arquivo)
    tempo = []
    temperatura = []
    for linha in file:
        tempo.append(linha['tempo'])
        temperatura.append(linha['temperatura'])

# %%
from matplotlib import pyplot as plt
#
plt.plot(tempo, temperatura)
# Out:
# Text(0.5, 0, '')

# %% [markdown]
# # Propriedades físico-químicas
#
# * Estrutural
# * Dinâmico
# * Vibracional
# * Termodinâmico
# * Eletromagnético

# %% [markdown]
# # Propriedades físico-químicas
#
# ## Estrutural
#
# ### Função de distribuição radial

# %% [markdown]
# # Propriedades físico-químicas
#
# ## Dinâmico
#
# ### Função de distribuição radial

# %% [markdown]
# # Propriedades físico-químicas
#
# ## Termodinâmico
#
# ### Energia interna, temperatura, pressão, calor específico, ...
