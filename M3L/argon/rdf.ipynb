# %%
import numpy as np
#
natom = 250
dataset = np.loadtxt("history.csv", dtype = np.float32, delimiter = ",", skiprows=1)
frames = int(len(dataset)/natom)
print(frames)
print()
print(dataset)
# Out:
# 1000
#
# [[  0.        -16.429998    4.233888    1.9229125]
#  [  0.          8.544187    1.5181392 -11.406284 ]
#  [  0.         -4.348952    1.6118872  -2.3730845]
#  ...
#  [  4.995     -16.672398  -12.393558   -2.6960964]
#  [  4.995       1.1895921  -9.484976   -7.6205482]
#  [  4.995     -25.937464  -14.05347    11.183124 ]]

# %%
import time
#
start = time.time()
dataset = dataset[:natom*frames, 1:4]
xyz = np.reshape(dataset, (frames, natom, 3))
#print(xyz)
print(xyz.shape)
print(xyz)
#volume_df = np.loadtxt("thermodynamics.csv", dtype = np.float32, delimiter = ",", skiprows = 1)
#volume_df = volume_df[:natom*rep, 1]
#print(volume_df)
# Out:
# (1000, 250, 3)
# [[[-16.429998    4.233888    1.9229125]
#   [  8.544187    1.5181392 -11.406284 ]
#   [ -4.348952    1.6118872  -2.3730845]
#   ...
#   [-12.50215   -13.760784   -2.598638 ]
#   [  2.5306876  -6.292821   -5.560896 ]
#   [-24.750572  -14.830562    8.353678 ]]
#
#  [[-16.432474    4.2387085   1.9214708]
#   [  8.535762    1.5093234 -11.404311 ]
#   [ -4.352592    1.6070068  -2.3702168]
#   ...
#   [-12.521743  -13.751286   -2.6016955]
#   [  2.531239   -6.302516   -5.5636353]
#   [-24.74136   -14.825022    8.364517 ]]
#
#  [[-16.4354      4.2431164   1.920346 ]
#   [  8.527318    1.5003295 -11.402213 ]
#   [ -4.35626     1.6021761  -2.3671496]
#   ...
#   [-12.541663  -13.741875   -2.6044893]
#   [  2.5318377  -6.312027   -5.5663533]
#   [-24.732328  -14.818995    8.375306 ]]
#
#  ...
#
#  [[-16.947685    4.2823863   1.764155 ]
#   [ 10.044853    1.5331205 -13.07925  ]
#   [ -5.1209674   1.9288661  -1.4520996]
#   ...
#   [-16.657885  -12.389948   -2.6871629]
#   [  1.1801842  -9.468931   -7.6415815]
#   [-25.92276   -14.060615   11.172755 ]]
#
#  [[-16.94929     4.2842255   1.7588356]
#   [ 10.04259     1.5413684 -13.069871 ]
#   [ -5.114557    1.929014   -1.4476013]
#   ...
#   [-16.665165  -12.391608   -2.6916878]
#   [  1.1849161  -9.476891   -7.63109  ]
#   [-25.930035  -14.057354   11.178077 ]]
#
#  [[-16.950926    4.2859974   1.7536658]
#   [ 10.040038    1.549239  -13.060423 ]
#   [ -5.1082344   1.9289756  -1.4432411]
#   ...
#   [-16.672398  -12.393558   -2.6960964]
#   [  1.1895921  -9.484976   -7.6205482]
#   [-25.937464  -14.05347    11.183124 ]]]

# %%
from m3l.structure import System as sys
import json
#
system = sys()
system.loadSystem('Ar_84K.json')
cell = [item.item() for item in system.cell]
print(cell)
# Out:
# [22.82, 22.82, 22.82]

# %%
def mic(x, y, z):
    x = x - cell[0]*int(2.0*x/cell[0])
    y = y - cell[1]*int(2.0*y/cell[1])
    z = z - cell[2]*int(2.0*z/cell[2])
    var = np.sqrt(x**2+y**2+z**2)    
    return var
#
r = []
for i in range(frames):
    for j in range(natom):
        for k in range(j+1, natom):
            x = (xyz[i, k, 0]-xyz[i, j, 0])
            y = (xyz[i, k, 1]-xyz[i, j, 1])
            z = (xyz[i, k, 2]-xyz[i, j, 2])
#            var = np.sqrt(x**2+y**2+z**2)    
            var = mic(x, y, z)
            r.append(var.item())

# %%
rl0 = 2.0
rlmax = 0.5*min(cell[0], cell[1], cell[2])
dr = 0.1
nx = int((rlmax-rl0)/dr)
dr = (rlmax-rl0)/float(nx)
rl = np.linspace(rl0, rlmax, num = nx)
gr = []
for dri in rl:
    count = 0
    for item in r:
        if item > dri and item <= (dri+dr):
            count += 2
    vol = 4.0*3.14*dr*dri**2
    gr.append(count*cell[0]*cell[1]*cell[2]/(natom*natom*vol*frames))
#
end = time.time()
print(f'Elapsed time: {end - start}')
# Out:
# Elapsed time: 823.1204090118408

# %%
# dados experimentais
xl = [3.211, 3.309, 3.374, 3.52, 3.634, 3.747, 3.894, 4.04, 4.267, 4.43, 4.836, 5.194, 5.632, 5.957, 6.282, 6.77, 7.111, 7.484, 7.842, 8.183, 8.459, 8.817, 11.465, 12.001]
yl = [0.042, 0.207, 1.056, 2.498, 3.301, 3.347, 2.9, 1.938, 1.444, 1.056, 0.47, 0.503, 0.681, 0.826, 1.016, 1.188, 1.174, 1.069, 0.997, 0.964, 0.944, 0.951, 0.984, 0.997]

# %%
from matplotlib import pyplot as plt
plt.scatter(xl, yl, marker = '.', color = 'black')
plt.hlines(y = 1.0, xmin = min(rl), xmax = max(rl), linestyle = 'dotted', color = 'red')
plt.plot(rl, gr)
plt.ylabel('RDF')
plt.xlabel('r')
plt.xticks([2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5])
#plt.xlim(rl0, rlmax)
#plt.ylim(0, 0.1)
plt.savefig("RDF.jpg")

# %%
sigma = 3.405
eps = 0.2383
xlista = np.arange(3.2, 12, 0.1)
ylista = map(lambda u: 4*eps*((sigma/u)**12-(sigma/u)**6), xlista)
plt.plot(xlista, list(ylista))
plt.hlines(y = 0.0, xmin = 3.2, xmax = 12, linestyle = 'dotted', color = 'red')

# %%
import csv
#
with open('rdf.csv', 'w') as file:
    objeto = csv.DictWriter(file, fieldnames = ['r', 'gr'])
    objeto.writeheader()
    for i in range(len(gr)):
        objeto.writerow({'r': rl[i], 'gr': gr[i]})
#
with open('rdf_exp.csv', 'w') as file:
    objeto = csv.DictWriter(file, fieldnames = ['r', 'gr'])
    objeto.writeheader()
    for i in range(len(xl)):
        objeto.writerow({'r': xl[i], 'gr': yl[i]})
