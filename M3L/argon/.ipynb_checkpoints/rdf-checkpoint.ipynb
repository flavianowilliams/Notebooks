# %%
import numpy as np
#
natom = 250
dataset = np.loadtxt("history.csv", dtype = np.float32, delimiter = ",", skiprows=1)
frames = int(len(dataset)/natom)
print(frames)
print()
print(dataset)
# Out:
# 1000
#
# [[  0.         -18.328352     4.32164      4.9022818 ]
#  [  0.           9.705599    -0.48970947 -11.367741  ]
#  [  0.          -5.642587     2.4728887   -2.29349   ]
#  ...
#  [  4.995      -12.482919   -13.770373    -2.5953176 ]
#  [  4.995        2.5301652   -6.2829843   -5.558116  ]
#  [  4.995      -24.759966   -14.835592     8.342799  ]]

# %%
import time
#
start = time.time()
dataset = dataset[:natom*frames, 1:4]
xyz = np.reshape(dataset, (frames, natom, 3))
#print(xyz)
print(xyz.shape)
print(xyz)
#volume_df = np.loadtxt("thermodynamics.csv", dtype = np.float32, delimiter = ",", skiprows = 1)
#volume_df = volume_df[:natom*rep, 1]
#print(volume_df)
# Out:
# (1000, 250, 3)
# [[[-18.328352     4.32164      4.9022818 ]
#   [  9.705599    -0.48970947 -11.367741  ]
#   [ -5.642587     2.4728887   -2.29349   ]
#   ...
#   [-11.410612   -13.035703    -1.5164186 ]
#   [  2.529705    -7.0231338   -5.68249   ]
#   [-23.097893   -13.816195     8.330882  ]]
#
#  [[-18.322989     4.3214283    4.905816  ]
#   [  9.699059    -0.47545943 -11.359335  ]
#   [ -5.6539173    2.4787912   -2.2959692 ]
#   ...
#   [-11.413575   -13.035287    -1.5209364 ]
#   [  2.5351465   -7.0242505   -5.6863008 ]
#   [-23.091799   -13.815881     8.332381  ]]
#
#  [[-18.317926     4.319432     4.909989  ]
#   [  9.692497    -0.4611698  -11.350997  ]
#   [ -5.665298     2.4848452   -2.2987812 ]
#   ...
#   [-11.416372   -13.035353    -1.5253471 ]
#   [  2.5406296   -7.025371    -5.690105  ]
#   [-23.0867     -13.815519     8.333517  ]]
#
#  ...
#
#  [[-16.425272     4.216904     1.9291501 ]
#   [  8.569377     1.5434387  -11.411326  ]
#   [ -4.338283     1.6267309   -2.3803244 ]
#   ...
#   [-12.44569    -13.789839    -2.5878928 ]
#   [  2.5291383   -6.263045    -5.5523663 ]
#   [-24.779306   -14.8440275    8.320964  ]]
#
#  [[-16.4264       4.222988     1.926754  ]
#   [  8.560989     1.5352045  -11.409803  ]
#   [ -4.3417883    1.6217597   -2.378155  ]
#   ...
#   [-12.464086   -13.780057    -2.5917351 ]
#   [  2.5296545   -6.273046    -5.5552783 ]
#   [-24.769545   -14.840088     8.331891  ]]
#
#  [[-16.427975     4.228649     1.9246737 ]
#   [  8.552594     1.5267688  -11.408119  ]
#   [ -4.345348     1.6168082   -2.3757362 ]
#   ...
#   [-12.482919   -13.770373    -2.5953176 ]
#   [  2.5301652   -6.2829843   -5.558116  ]
#   [-24.759966   -14.835592     8.342799  ]]]

# %%
from m3l.structure import System as sys
import json
#
system = sys()
system.loadSystem('Ar_84K.json')
cell = [item.item() for item in system.cell]
print(cell)
# Out:
# [22.82, 22.82, 22.82]

# %%
def mic(x, y, z):
    x = x - cell[0]*int(2.0*x/cell[0])
    y = y - cell[1]*int(2.0*y/cell[1])
    z = z - cell[2]*int(2.0*z/cell[2])
    var = np.sqrt(x**2+y**2+z**2)    
    return var
#
r = []
for i in range(frames):
    for j in range(natom):
        for k in range(j+1, natom):
            x = (xyz[i, k, 0]-xyz[i, j, 0])
            y = (xyz[i, k, 1]-xyz[i, j, 1])
            z = (xyz[i, k, 2]-xyz[i, j, 2])
#            var = np.sqrt(x**2+y**2+z**2)    
            var = mic(x, y, z)
            r.append(var.item())

# %%
rl0 = 2.0
rlmax = 0.5*min(cell[0], cell[1], cell[2])
dr = 0.1
nx = int((rlmax-rl0)/dr)
dr = (rlmax-rl0)/float(nx)
rl = np.linspace(rl0, rlmax, num = nx)
gr = []
for dri in rl:
    count = 0
    for item in r:
        if item > dri and item <= (dri+dr):
            count += 2
    vol = 4.0*3.14*dr*dri**2
    gr.append(count*cell[0]*cell[1]*cell[2]/(natom*natom*vol*frames))
#
end = time.time()
print(f'Elapsed time: {end - start}')

# %%
# dados experimentais
xl = [3.211, 3.309, 3.374, 3.52, 3.634, 3.747, 3.894, 4.04, 4.267, 4.43, 4.836, 5.194, 5.632, 5.957, 6.282, 6.77, 7.111, 7.484, 7.842, 8.183, 8.459, 8.817, 11.465, 12.001]
yl = [0.042, 0.207, 1.056, 2.498, 3.301, 3.347, 2.9, 1.938, 1.444, 1.056, 0.47, 0.503, 0.681, 0.826, 1.016, 1.188, 1.174, 1.069, 0.997, 0.964, 0.944, 0.951, 0.984, 0.997]

# %%
from matplotlib import pyplot as plt
plt.scatter(xl, yl, marker = '.', color = 'black')
plt.hlines(y = 1.0, xmin = min(rl), xmax = max(rl), linestyle = 'dotted', color = 'red')
plt.plot(rl, gr)
plt.ylabel('RDF')
plt.xlabel('r')
plt.xticks([2, 2.5, 3, 3.5, 4, 4.5, 5, 5.5, 6, 6.5])
#plt.xlim(rl0, rlmax)
#plt.ylim(0, 0.1)
plt.savefig("RDF.jpg")

# %%
sigma = 3.405
eps = 0.2383
xlista = np.arange(3.2, 12, 0.1)
ylista = map(lambda u: 4*eps*((sigma/u)**12-(sigma/u)**6), xlista)
plt.plot(xlista, list(ylista))
plt.hlines(y = 0.0, xmin = 3.2, xmax = 12, linestyle = 'dotted', color = 'red')

# %%
import csv
#
with open('rdf.csv', 'w') as file:
    objeto = csv.DictWriter(file, fieldnames = ['r', 'gr'])
    objeto.writeheader()
    for i in range(len(gr)):
        objeto.writerow({'r': rl[i], 'gr': gr[i]})
#
with open('rdf_exp.csv', 'w') as file:
    objeto = csv.DictWriter(file, fieldnames = ['r', 'gr'])
    objeto.writeheader()
    for i in range(len(xl)):
        objeto.writerow({'r': xl[i], 'gr': yl[i]})
