# %% [markdown]
# # Neste notebook faremos a simulação por dinâmica molecular do gás argônio superfluido à 94 K e 1 atm.

# %% [markdown]
# Antes de dar início à simulação, deveremos instalar o pacote M3L responsável pela dinâmica molecular. Descomente a linha abaixo caso ele ainda não foi instalado no seu ambiente virtual.

# %%
#pip install -i https://test.pypi.org/simple/ m3l --extra-index-url https://pypi.org/simple/

# %% [markdown]
# ## Etapa 1
# O primeiro passo consiste em definirmos o sistema físico contendo as coordenadas atômicas. Descomente as cinco primeiras linhas abaixo para fazer o download do arquivo "Ar_94K_1atm.json".

# %%
#url = 'https://raw.githubusercontent.com/flavianowilliams/Notebooks/master/M3L/argon/Ar_94K_1atm.json'
#from urllib.request import urlopen
#file = urlopen(url)
#with open('Ar_94K.json','wb') as output:
#  output.write(file.read())
#
# carregando sistema físico
from m3l.structure import System as sys
import json
#
system = sys()
system.loadSystem('Ar_94K.json')
#
# convertendo as unidades de medida
system.convertUnits()
# Out:
# [[-7.60503016e+00  4.37213963e+01  9.03396264e+00]
#  [-2.07823598e+01 -1.19767298e+01 -2.79746501e+01]
#  [ 7.03346666e+01  2.74880944e+01  7.42124779e-01]
#  [ 9.66330808e+01 -8.48363025e+00  1.69881447e+01]
#  [ 1.17655684e+01 -4.59682856e+01  4.00049282e+01]
#  [ 3.56748129e+01  1.98806062e+01 -5.62033502e+01]
#  [-1.92506496e+01  2.57054576e+01 -3.19375914e+00]
#  [ 1.61528516e+01 -1.25031013e+01  3.25747828e+00]
#  [-4.02780186e+01 -4.73527726e+01  2.10655394e+01]
#  [ 8.28589347e+00 -2.67741357e+01 -4.75729254e+00]
#  [-2.32344144e+01  1.39526151e+00 -3.06378977e+00]
#  [-1.26532752e+01 -3.95676857e+01  2.54321739e+01]
#  [ 2.88117513e+01  3.08526960e+01  5.67653883e+01]
#  [ 5.05148300e+01 -2.32379050e+01  3.28422818e+01]
#  [ 2.25770331e+01 -4.29744370e+01  9.94710360e+00]
#  [-3.65749750e+01  3.50119462e+01  2.38461745e+01]
#  [-4.51493747e+01  4.49966617e+00  3.75882239e+01]
#  [ 3.81277360e+01  2.16429065e+00 -3.31887952e+01]
#  [ 5.16437411e+00 -7.36979360e+01  2.73605970e+01]
#  [-1.76550126e+01  6.16020540e+01 -5.13716593e+01]
#  [ 2.73581008e+01 -7.69787130e+00 -1.79930328e-01]
#  [-1.12106119e+01 -1.28681109e+00  1.88337635e+01]
#  [-5.64620013e+01  1.20355251e+01  3.54120620e+01]
#  [-1.58104065e+01 -1.30770180e+01 -2.05576705e+01]
#  [ 8.40217118e+01  3.68668543e+01  2.37847022e+01]
#  [-4.66527541e+01  1.63496310e+01  7.57690547e-01]
#  [ 3.27920269e+01  3.58015206e+00  3.09741114e+01]
#  [-1.11101783e+01 -3.12079050e+01  3.98892309e+01]
#  [-1.00097812e+01  1.68018316e+01  2.61164950e+01]
#  [ 5.78256256e+01 -7.65434200e+00  7.31421568e-01]
#  [-1.23467040e+00  7.80745831e+00  1.84701826e+01]
#  [-6.66946920e+00 -8.41858703e+00  2.53083609e+00]
#  [-3.47529293e+01 -4.65901453e+01  1.42534314e+00]
#  [-4.35926904e+01 -2.93667020e+01  1.00020943e+01]
#  [-1.96486251e+00 -1.97426913e+00 -4.68945105e+00]
#  [-2.81760781e+01 -4.51884367e+01 -8.34707055e+00]
#  [-7.21649866e+01 -5.25691911e+01 -8.05005617e+01]
#  [-7.18221596e+01 -2.06584732e+01  1.37229530e+01]
#  [-3.59325941e+00  2.49053929e+01  1.12111517e+01]
#  [ 1.33600383e+01  9.86941933e+00  1.65545754e+00]
#  [ 8.46734270e+01 -1.74637603e+01  4.98133374e+01]
#  [-1.02686812e+01  3.33079006e+01  4.48003663e+01]
#  [ 2.00900181e+01 -6.96712836e+01 -1.80524334e+01]
#  [ 7.39210939e+01  2.33278359e+01 -1.94445194e+01]
#  [-2.18612003e+01  5.67230698e+01 -4.04624153e+01]
#  [-4.56347025e+01  1.79845835e+01  2.06929926e+01]
#  [ 5.12749844e+01 -7.56139019e+01  1.63154887e+01]
#  [-1.40285376e+01  4.07730164e+00  4.02046205e+01]
#  [ 6.28650455e+01  5.06135426e+01  4.41098631e+01]
#  [ 2.77444767e+00 -3.02042083e+01  6.86942879e+00]
#  [-1.46016079e+01  5.86416310e+01  1.01978904e+01]
#  [-1.89909220e+01  1.10668998e+01  2.81322343e+01]
#  [ 9.69771232e+00 -3.73493494e+01 -7.09553007e+00]
#  [-4.95385119e-01 -2.91177679e+01 -1.42397255e+01]
#  [-4.78789420e+01 -1.06925598e+00 -6.63313294e+01]
#  [ 8.91632379e+01  2.17175399e+01 -3.08746055e+01]
#  [-6.15709882e+01  9.33294203e-01 -4.86994051e+00]
#  [ 1.30081421e+01  3.35866927e+01  1.75763650e+01]
#  [ 4.86148650e+01  6.00817924e+01 -1.73731332e+01]
#  [-2.28619122e+01 -2.12131615e+01 -1.93032252e+01]
#  [-9.37749419e+00  3.65713197e+01  2.85465845e+01]
#  [-1.02447705e+02 -6.31759348e+01  5.97370182e+00]
#  [-1.57059327e+01  3.02194153e+01  1.25575459e+01]
#  [ 3.92236576e+00 -3.88578640e+01  2.08024284e+01]
#  [ 4.56073046e+01 -1.66286997e+01 -4.05617084e+01]
#  [ 2.05893944e+01  2.95629654e+01 -3.23541561e+01]
#  [-4.45874406e+01  5.80104521e+01 -5.13480684e-01]
#  [ 3.23798919e+01  2.39707999e+01 -2.01173535e+01]
#  [ 7.86111120e+01 -2.95957680e+01  3.11163264e+00]
#  [ 2.34951810e+01  8.95500696e-01  8.71526721e+00]
#  [-3.51048756e+00  5.98920174e+01  1.75015777e+01]
#  [-2.46649856e+01 -4.00150762e+01 -2.52025195e+01]
#  [ 2.11078211e+01 -3.73923156e+01 -1.16247965e+01]
#  [-1.21779591e+01  1.97527698e+01 -2.12549218e+01]
#  [ 1.70004434e+00  2.88867774e+01 -2.64496301e+01]
#  [-3.87724766e+00 -1.74516661e+01 -1.22266622e+01]
#  [-5.59637016e+01 -2.58375804e+01  4.95476688e+01]
#  [ 2.99263820e+01  3.09905626e+01 -7.38568490e+00]
#  [-4.33607454e+00 -7.59560375e+01  3.12066383e+01]
#  [-3.26756142e+01  1.64667618e+01 -1.69529520e+01]
#  [-4.55039869e+01 -5.10982694e+01  1.36201824e+01]
#  [ 8.48595637e+00  1.35206958e+01  5.35355275e+01]
#  [-7.29884021e+00 -1.98946141e+01 -1.41917073e+01]
#  [-2.98704250e+01 -2.09617298e+01 -2.04433551e+01]
#  [ 9.11123390e+00  3.10739270e+01 -3.78252413e+01]
#  [ 2.24069324e+01  1.23673394e+01  2.39182722e+01]
#  [ 2.85019904e+01  3.79117684e+01 -4.10410192e+01]
#  [ 1.96902026e+01  9.86630847e+00  1.52172231e+01]
#  [-1.24354174e+01 -5.60727123e+01 -1.38465660e+01]
#  [ 1.90563883e+01  3.31159468e+01 -2.51288167e+01]
#  [ 3.28616558e+01  2.20968654e+01 -3.14452129e+01]
#  [-3.11461373e+00 -5.26564994e+00 -6.69571437e+00]
#  [ 2.98298813e+01 -5.73978055e+00  3.07229090e+01]
#  [-1.81944981e+01 -1.02187702e+01  1.54701849e+01]
#  [-5.52796642e+01  2.08870286e+01 -1.56938165e+00]
#  [ 2.85725783e+00  3.97581073e+01 -5.69886902e+01]
#  [ 6.97678368e+01 -5.45802401e+01  1.81353591e+01]
#  [-2.13433792e+01  3.03141382e+00 -5.97017232e+00]
#  [-3.53251760e+01  1.42650036e+01  2.07849561e+01]
#  [ 1.41668369e+01  5.05628102e+01 -6.51230191e+01]
#  [-3.06956504e+00  2.46871768e+01 -2.82886833e+01]
#  [-5.33402297e+01  8.11496091e+01  4.14748849e+01]
#  [-4.01084692e+01 -2.30032455e+01 -3.58276058e+01]
#  [ 1.19039306e+01  2.15820576e+01  9.26989286e+01]
#  [-7.66366233e+00 -7.97917866e+01 -7.63205658e+01]
#  [-6.65270049e+01 -2.29009210e+01  8.55304518e+01]
#  [-1.66766112e+01 -3.21587458e+01  3.26070664e+01]
#  [-2.84750374e+01  7.83207076e+01 -3.87402522e+01]
#  [ 3.02794096e+00  7.02010255e+00  1.73527764e+01]
#  [ 1.51918994e+01  2.25145938e+01  1.50000641e+01]
#  [ 3.26824791e+01  3.43828863e+01 -3.21267550e+00]
#  [ 5.59647514e+00  1.88155280e+01  2.43193910e+01]
#  [ 3.77927471e+01 -5.69503483e+01  3.21749095e+01]
#  [-2.99472925e+01 -4.65357070e+01  7.34079892e+00]
#  [-7.40069020e+00 -3.49067838e+01 -3.20234756e+01]
#  [ 3.80494862e+01  3.06771365e+01 -2.89414623e+01]
#  [ 5.19554299e+00 -2.80663870e+01  2.07687023e+01]
#  [ 1.12968752e+02  7.39056651e+00 -5.32418173e+01]
#  [-1.83731014e+01 -1.46370387e+01 -6.93117496e+01]
#  [ 6.24036589e+00  1.78563017e+01 -1.07731683e+01]
#  [-1.07469576e+01  7.51997764e+01 -1.18227074e+01]
#  [-1.81351299e+01  5.80832056e+01 -1.49941933e+01]
#  [ 2.50146792e+01  1.89907307e+01  2.71473346e+01]
#  [-1.27124437e+01  1.25276258e+01 -1.99380306e+01]
#  [ 5.96419381e+00  2.72176861e+01 -5.34518121e+01]
#  [-1.26672906e+01  7.35929691e+00 -2.70323483e+01]
#  [ 3.73957037e+01  1.53985240e+01  6.02178461e+01]
#  [-3.41587961e+01 -3.83244524e+00  2.89662100e+01]
#  [-4.12520203e+01 -4.36378324e+01  3.66462325e+01]
#  [-1.37937368e+01  2.38721648e+00 -3.36577696e+01]
#  [-3.63322966e+01 -1.47803672e+01  1.33048118e+01]
#  [ 8.30637605e+01  9.34670239e+00 -1.76090515e+01]
#  [ 3.28198661e+01 -2.15649393e+01  1.59327061e-01]
#  [-3.12536105e+00  3.64109928e+01 -4.95343877e+01]
#  [-2.63888620e+01  1.44711405e+00  2.26130273e+01]
#  [ 1.66250038e+01  6.99192211e+00  2.07895857e+01]
#  [-6.03217424e+01  1.78072851e+01 -4.94868821e+01]
#  [ 1.00176756e+01 -6.66020109e+00  1.30476747e+01]
#  [ 5.46953712e+01  3.04589588e+01 -7.44569339e+01]
#  [ 6.51453786e+00 -2.62474199e+01  9.15006843e+00]
#  [-5.44861008e+01 -7.01560288e+01  2.46303106e-01]
#  [-4.39548995e+01 -1.40321152e+01  3.50688178e+01]
#  [ 3.16591282e+01  5.55817141e+01 -7.14176467e+01]
#  [ 5.45238710e+00 -2.01525492e+01 -1.84240401e+01]
#  [ 4.68896304e+01 -7.96109854e+00 -1.93428182e+01]
#  [ 1.84259961e+01 -1.45326758e+00  2.62333969e+01]
#  [-2.69540872e+01 -3.43600825e+01  7.35762229e+01]
#  [-4.66252505e+01  7.64800990e+00  9.78077067e+00]
#  [-4.60656372e+01 -2.39070794e+01  1.19201028e+01]
#  [ 5.24888295e+01  5.50076009e+00 -4.66662253e+01]
#  [ 1.97348445e+01 -4.88168916e+01  8.17819207e+00]
#  [ 6.84218474e+01  1.12054640e+02 -2.59226262e+01]
#  [ 4.74040284e+01 -3.92206285e+00 -3.01067759e+01]
#  [-3.48291613e+01  2.34345562e+01 -1.20554358e+01]
#  [-8.10600469e+01  2.75951385e+01  1.80874546e+01]
#  [ 2.49127476e+00 -3.27409114e+01  9.77578259e+00]
#  [ 4.70735934e+00 -2.53106027e+01  1.83522834e+01]
#  [-2.76991885e+01  1.54215189e+01  1.13643612e+01]
#  [-4.59258927e+01 -4.75404853e+01 -6.17935003e+00]
#  [-6.25951058e+00 -1.85378499e+01  7.07420475e+01]
#  [-1.51067582e+01 -9.29640459e+00 -4.81783906e+01]
#  [-3.08416613e+01 -1.13834372e+01  2.18464238e+01]
#  [-1.18112282e+01  1.87899956e+00  4.41934243e+01]
#  [ 7.08637454e+01 -1.53960739e+01  1.46150892e+01]
#  [-3.08601665e+00  1.58430041e+01 -4.59518999e+01]
#  [ 4.19953574e+00  6.85143504e+00  1.33159332e+01]
#  [ 1.65896482e+00 -5.78584438e+01 -8.05624410e+01]
#  [ 5.25592119e-01 -7.03140667e+01  4.79028821e+01]
#  [-7.30368589e+01 -1.67751513e+01  2.86010484e+00]
#  [ 5.18621746e+01 -2.36792788e+00  1.22893117e+01]
#  [-2.39938503e+01  1.10005682e+01 -6.46690721e+00]
#  [-1.62675412e+01 -6.45493865e+01 -2.02288229e+01]
#  [-8.96100147e+00  8.68999868e+00 -3.28897761e+01]
#  [-4.14349850e+01  3.53702224e+01 -4.89328001e+01]
#  [-6.23878425e+01  3.99623117e+01 -7.77234111e+01]
#  [ 1.15457181e+01 -1.96770996e+00 -1.50796124e+01]
#  [ 3.94557931e+00 -1.66652153e+01  6.59138258e+00]
#  [ 2.98497887e+01 -4.30898418e+01 -3.76939462e+01]
#  [-2.85819181e+01  4.29529142e+01  1.94586004e+01]
#  [ 2.18772046e+01 -2.41701806e+01 -1.02847603e+02]
#  [-4.88979400e+01  1.08138728e+01  3.01745443e+01]
#  [ 6.48458237e+01 -6.31943154e+00 -8.86496750e+00]
#  [ 3.06044085e+01  1.40703653e+01 -2.05379398e+01]
#  [ 1.21733300e+01 -4.11790354e+01  1.49907244e+01]
#  [-2.46966508e+01  4.55447738e+00  1.70518805e+01]
#  [ 1.83859294e+01 -3.95555604e+00 -2.38238724e+01]
#  [ 9.16607110e+00 -3.40330243e+01  4.09015060e+01]
#  [-7.90000967e+00  3.97046840e+01  2.19653548e+01]
#  [-1.07343501e+01  5.89127966e+00 -6.22009528e+01]
#  [ 1.96403137e+01 -2.91382918e+00  1.22204605e+01]
#  [ 3.24929598e+00  3.36518671e+01  3.89178429e+01]
#  [-4.10447517e+01 -2.41441104e+01  1.43266729e+00]
#  [-2.72303178e+01  4.47078004e+00  4.45334754e+01]
#  [-1.80363324e+00 -4.20806996e+00  2.50603690e+00]
#  [-6.07536350e+00 -3.45415288e+01  1.00683045e+01]
#  [ 4.33946932e+01  6.31913020e+01  2.83506669e+01]
#  [ 3.44529462e+01  2.67317344e+01  2.94535697e+00]
#  [ 4.15652439e+01  2.26044428e+01 -2.58932646e+01]
#  [ 5.56076874e+01 -2.86956141e+00 -2.39450566e+01]
#  [ 5.35973000e+01  2.34591754e-02  6.45751766e+00]
#  [ 2.92979457e+00  2.82249644e+01 -1.27965136e+01]
#  [ 1.81652583e+01  2.92769502e+01 -4.24714396e+01]
#  [-3.40210291e+01 -2.80079602e+01 -3.76134315e+00]
#  [ 4.91340644e+01 -6.71321392e+01  5.41663487e+01]
#  [ 1.55363815e+01  2.38832597e+01  1.87958873e+01]
#  [ 1.57847669e+00 -2.70694798e+01 -4.08884731e-02]
#  [ 8.96229010e+00 -5.03992905e+01  1.20806922e+01]
#  [ 3.26202914e+01 -2.86269627e+01  3.22248587e+01]
#  [-7.14568248e+00 -5.40374522e+01  1.01732524e+01]
#  [-4.52364993e+01 -3.39320304e+01 -4.47407792e+01]
#  [ 2.88922736e+01  1.37645934e+01 -1.15924073e+01]
#  [-1.79981382e+00  6.84064706e+01 -2.45701721e+01]
#  [ 5.11445423e+01 -3.06067417e+01  3.43147224e+00]
#  [-2.64926780e+01 -2.07209967e+01 -2.09870667e+01]
#  [-1.45936321e+01  2.04744442e+01 -1.82416284e+01]
#  [-2.54106325e+01  3.67286431e+01  1.08521154e+02]
#  [-5.39857355e+01  5.26084150e+01  1.29185197e+01]
#  [ 3.19949202e+00  2.63248335e+01 -4.61999628e+01]
#  [-6.96666812e+00 -7.68835550e-03 -3.55305936e+01]
#  [-1.00148992e+02  8.31708137e+00 -2.20888200e+01]
#  [ 3.56457579e+01  3.38093978e+01 -6.12084382e+01]
#  [-3.43824072e+01 -5.05496194e+00 -3.63069711e+01]
#  [ 2.42946873e+00 -6.49363198e+01  3.26404466e+00]
#  [ 3.45688136e-01 -9.53191488e+00  4.47135628e+01]
#  [ 3.95467298e+01  1.96651877e+01  3.62356526e+01]
#  [-2.22963203e+00 -8.63965034e+00  5.47548610e+01]
#  [-4.33058328e+01  2.01940902e+01  7.74806449e+01]
#  [-3.97881100e+01  3.23747951e+01  6.19311213e+00]
#  [ 1.12164879e+01  2.94332985e+01  5.19805356e+00]
#  [-2.81543494e+01  9.08418008e+00 -1.83732937e+01]
#  [ 1.52083268e+00  7.50291477e+00 -2.29247131e+01]
#  [-4.10108155e+01 -3.65483249e+01  4.20053081e+01]
#  [-4.99337319e+00 -3.14902595e+01 -3.64189663e+00]
#  [ 2.22136953e+01 -2.76385140e+01  6.02344284e+00]
#  [ 3.90184702e+01 -3.95814856e+00  1.67173471e+01]
#  [ 1.69539025e+01  5.12630713e+01 -5.37401960e+01]
#  [ 3.62690864e+01  4.91486244e+01  8.39451390e+00]
#  [ 3.01300776e+01 -3.72103804e+01 -3.47876631e+01]
#  [-1.47113502e+01 -1.10020263e+01  1.37187560e+01]
#  [ 9.38305960e+01 -1.31691254e+01  2.07952708e+01]
#  [-3.10556826e+01  1.05116220e+01  3.10395648e+01]
#  [ 1.20671809e+01  1.21569576e+01  1.45340078e+01]
#  [ 9.36496529e+00  5.34541274e+00 -9.94044605e-01]
#  [-3.61149305e+01  3.94076039e+01 -1.86308813e+01]
#  [-4.71847627e+01 -1.37877767e+01  5.01464092e+01]
#  [-5.28137097e+01  3.75037429e+01 -4.04652814e+01]
#  [-3.36463881e+01 -6.61930744e+01 -3.87312454e-01]
#  [-6.58300901e+00  7.94481354e+01 -1.23385981e+01]
#  [ 4.30761692e+01  3.52790632e+00  3.17760237e+01]
#  [ 3.67200132e+01 -2.36703451e+01  2.87819345e+01]]

# %% [markdown]
# ## Etapa 2
# O segundo passo consiste em definirmos o modelo para o campo de força. Neste caso consideraremos uma molécula contendo apenas um sítio atômico com interações intermoleculares do tipo Van der Waals representado pela função Lennard-Jones de dois parâmetros, como mostra a figura abaixo.
#
# ![lennard-jones](../contrib/lennard-jones.jpeg)

# %%
# definindo o modelo de interação entre os átomos (campo de força)      
import m3l.force_field as ff
from m3l.force_field import Intermolecular as interff
from m3l.force_field import Molecules as mo
class Forces(ff.ForceField2):
    def __init__(self):
        super().__init__()
        self.van_der_waals = self.sites(
            interff.site(1, 1, 0.2385, 3.4), #site ID, atomic charge, Lennard-Jones parameters
        )
        self.electrostatic = 'coulomb'
        self.convertUnits()
#        self.molecules = mo.molecule(1),
#        )
#    def intermolecular(self.van_der_waals, rvdw = 11.0, rcoul = 11.0)
#        return self.van_der_waals
#        
model = Forces()
model()
# Out:
# (1, 0.0, 0.0, [[[1, 1]], [[0.0003802000129863748, 6.42506882808646]]])

# %% [markdown]
# ## Etapa 3
# O terceiro passo consiste em definir o modelo estatístico (ensemble canônico) que descreverá o sistema no equilíbrio termodinâmico.

# %%
# Etapa 3
# definindo o modelo estatístico (ensemble)
from m3l.molecular_dynamics import Ensemble as en
#
force_field = model()
ensemble = en(temp_bath = 94, timestep = 1.0e-3, force_field = force_field, tstat = 2.0)
#ensemble = en(temp_bath = 94, press_bath = 1000.0, timestep = 1.0e-3, force_field = force_field, tstat = 2.0, pstat = 2.0)
system = ensemble(system)

# %% [markdown]
# ## Etapa 4
# O quarto passo consiste na dinâmica molecular, onde as coordenadas atômicas são recalculadas a cada passo da simulação em intervalos de tempo denominado de timestep. Opcionalmente o autor poderá registrar valores obtidos na simulação em arquivos de saída no formato csv.

# %%
# Etapa 4
# executando ciclo MD
import time
import csv
import numpy as np
#
n_steps = 10000
start = time.time()
with open('history.csv', 'w', newline = '') as csvfile1, open('thermodynamics.csv', 'w', newline = '') as csvfile2:
    fieldnames1 = ['x', 'y', 'z']
    writer1 = csv.DictWriter(csvfile1, fieldnames = fieldnames1)
    writer1.writeheader()
    fieldnames2 = ['time', 'volume', 'epotential', 'ekinetic', 'temperature', 'pressure']
    writer2 = csv.DictWriter(csvfile2, fieldnames = fieldnames2)
    writer2.writeheader()
    for step in range(n_steps):
        system = ensemble(system)
        if step%10 == 0:
            for ra in system.ra:
                writer1.writerow({
                    'x': ra[0]/system.ACONV,
                    'y': ra[1]/system.ACONV,
                    'z': ra[2]/system.ACONV,
                })
            writer2.writerow({
                'time': ensemble.dtimestep*step/system.TIMECONV, 
                'volume': system.volume/system.ACONV**3,
                'temperature': system.temperature/system.TEMPCONV,
                'epotential': system.epotential/system.ECONV,
                'ekinetic': system.ekinetic/system.ECONV,
                'pressure': system.pressure/system.PCONV})
#
end = time.time()
print(f'Elapsed time: {(end - start)/60} minutes')
# Out:
# Elapsed time: 0.021426141262054443 minutes

# %% [markdown]
# ## Etapa 5
# Esta etapa é opcional, onde o autor poderá salvar em um arquivo JSON o sistema físico obtido no final da simulação. Como opção, o autor poderá converter as unidades de medida em valores mais convenientes para a leitura e melhor interpretação do ponto de vista didático.

# %%
# Etapa opcional
# convertendo para as unidades de medida de entrada
system.convertUnitsInv()
#
# salvando sistema em arquivo JSON
system.save('Ar_94K.json')

# %% [markdown]
# ## Etapa 6
# Esta etapa é opcional, onde o autor poderá gerar gráficos das propriedades e analisar a sua evolução no tempo.

# %%
# Etapa opcional
# Gráfico de séries temporais de algumas variáveis termodinâmicas
import matplotlib.pyplot as plt
import numpy as np
import statistics as stats
dataset = np.loadtxt("thermodynamics.csv", dtype=np.float32, delimiter = ",", skiprows=1)
time = [item[0].item() for item in dataset]
vol = [item[1].item() for item in dataset]
epot = [item[2].item() for item in dataset]
ekin = [item[3].item() for item in dataset]
etotal = [item[2].item()+item[3].item() for item in dataset]
temp = [item[4].item() for item in dataset]
press = [item[5].item() for item in dataset]
#plt.plot(time, temp)
fig, axs = plt.subplots(2, 2, figsize = (10, 8))
# Energia potencial
axs[0, 0].plot(time, etotal)
axs[0, 0].set_title("Energia interna (kcal/mol)")
yp = round(stats.median(etotal), 0)
axs[0, 0].axhline(y = yp, color = 'red')
axs[0, 0].annotate(text = yp, xy = (0, yp), xytext = (0, yp), color = 'r')
# Energia cinética
#axs[1, 0].plot(time, ekin)
#axs[1, 0].set_title("Energia cinética (kcal/mol)")
#yp = round(stats.median(ekin), 0)
#axs[1, 0].axhline(y = yp, color = 'red')
#axs[1, 0].annotate(text = yp, xy = (0, yp), xytext = (0, yp), color = 'r')
# temperatura
axs[0, 1].plot(time, temp)
axs[0, 1].set_title("Temperatura (K)")
yp = round(stats.median(temp), 0)
axs[0, 1].axhline(y = yp, color = 'red')
axs[0, 1].annotate(text = yp, xy = (0, yp), xytext = (0, yp), color = 'r')
# pressão
axs[1, 1].plot(time, press)
axs[1, 1].set_title("Pressão (atm)")
yp = round(stats.median(press), 0)
axs[1, 1].axhline(y = yp, color = 'red')
axs[1, 1].annotate(text = yp, xy = (0, yp), xytext = (0, yp), color = 'r')
# volume
axs[1, 0].plot(time, vol)
axs[1, 0].set_title(r"Volume $\AA^3$")
yp = round(stats.median(vol), 0)
axs[1, 0].axhline(y = yp, color = 'red')
axs[1, 0].annotate(text = yp, xy = (0, yp), xytext = (0, 0.98*yp), color = 'r')
#
#fig.tight_layout()
#for ax in axs.flat:
#    ax.set(xlabel='Tempo (ps)')

# Hide x labels and tick labels for top plots and y ticks for right plots.
#for ax in axs.flat:
#    ax.label_outer()
fig.subplots_adjust(hspace = 0.5, wspace = 0.25)
#fig.set_figwidth(15)
#plt.rcParams.update({'font.size': 22})
plt.savefig("MD.jpg")

# %%
# limpando memória RAM
del model
del ensemble
del system
del dataset
